# %% [markdown]
# # **TOPIK: DATA PREPARATION FOR FORECASTING (A1)**

# %% [markdown]
# 1. Identifikasi dataset yang diberikan sebagai berikut:
# https://www.kaggle.com/adityadesai13/used-car-dataset-ford-and-mercedes
#
# 2. jelaskan kategori atau tipe data untuk masing - masing atribut atau variable
# 3. baca dataset tersebut dengan Python pandas dan berikan dokumentasi sederhana mengenai cara kerja

# %%
#MASUKAN JAWABAN A1 disini (jika jawaban merupakan isian, gunakan comment Python #
# 1. Datasheet tersebut merupakan datasheet tentang kumpulan mobil bekas di Inggris Raya
# 2. object, int64, int64, object, int64, object, int64, float64, float64
# 3.
from google.colab import drive
drive.mount('/content/drive/')

import pandas as pd
bmw = pd.read_csv("/content/drive/My Drive/datasheet/bmw.csv")
bmw
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#            model  year  price transmission  ...  fuelType  tax   mpg  engineSize
# 0       5 Series  2014  11200    Automatic  ...    Diesel  125  57.6         2.0
# 1       6 Series  2018  27000    Automatic  ...    Petrol  145  42.8         2.0
# 2       5 Series  2016  16000    Automatic  ...    Diesel  160  51.4         3.0
# 3       1 Series  2017  12750    Automatic  ...    Diesel  145  72.4         1.5
# 4       7 Series  2014  14500    Automatic  ...    Diesel  160  50.4         3.0
# ...          ...   ...    ...          ...  ...       ...  ...   ...         ...
# 10776         X3  2016  19000    Automatic  ...    Diesel  150  54.3         2.0
# 10777   5 Series  2016  14600    Automatic  ...    Diesel  125  60.1         2.0
# 10778   3 Series  2017  13100       Manual  ...    Petrol  200  42.8         2.0
# ...

# %% [markdown]
# # **TOPIK: DATA PREPARATION FOR CLUSTERING (A2)**

# %% [markdown]
# 1. Identifikasi dataset yang diberikan sebagai berikut:
# https://www.kaggle.com/vjchoudhary7/customer-segmentation-tutorial-in-python
#
# 2. jelaskan kategori atau tipe data untuk masing - masing atribut atau variable
# 3. baca dataset tersebut dengan Python pandas dan berikan dokumentasi sederhana mengenai cara kerja

# %%
# 1. Datasheet tersebut merupakan datasheet tentang kumpulan pelanggan disebuah mall
# 2. int64, object, int64, int64, int64
# 3.
mall = pd.read_csv("/content/drive/My Drive/datasheet/Mall_Customers.csv")
mall.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # **TOPIK: DATA PREPARATION FOR CLASSIFICATION (A3)**

# %% [markdown]
# 1. Identifikasi dataset yang diberikan sebagai berikut:
# https://www.kaggle.com/primaryobjects/voicegender
#
# 2. jelaskan kategori atau tipe data untuk masing - masing atribut atau variable
# 3. baca dataset tersebut dengan Python pandas dan berikan dokumentasi sederhana mengenai cara kerja

# %%
# 1. Datasheet tersebut merupakan datasheet tentang kumpulan pengenalan gender melalui suara
# 2. Tipe data untuk setiap variabel merupakan 'Float', kecuali variabel label yang mana merupakan 'object'
# 3. 
voice = pd.read_csv("/content/drive/My Drive/datasheet/voice.csv")
voice.head(5)
# Out:
#    meanfreq        sd    median       Q25  ...    maxdom   dfrange   modindx  label
# 0  0.059781  0.064241  0.032027  0.015071  ...  0.007812  0.000000  0.000000   male
# 1  0.066009  0.067310  0.040229  0.019414  ...  0.054688  0.046875  0.052632   male
# 2  0.077316  0.083829  0.036718  0.008701  ...  0.015625  0.007812  0.046512   male
# 3  0.151228  0.072111  0.158011  0.096582  ...  0.562500  0.554688  0.247119   male
# 4  0.135120  0.079146  0.124656  0.078720  ...  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
voice.dtypes
# Out:
# meanfreq    float64
# sd          float64
# median      float64
# Q25         float64
# Q75         float64
# IQR         float64
# skew        float64
# kurt        float64
# sp.ent      float64
# sfm         float64
# mode        float64
# centroid    float64
# meanfun     float64
# minfun      float64
# maxfun      float64
# meandom     float64
# mindom      float64
# maxdom      float64
# dfrange     float64
# modindx     float64
# label        object
# dtype: object

# %% [markdown]
# # **TOPIK: DATA PREPROCESSING FOR FORECASTING (B1)**

# %% [markdown]
# 1. Berdasarkan data A1 yang sudah anda baca, jelaskan tujuan dari forecasting apa yang ingin dilakukan?
#
# 2. jelaskan bagaimana cara mengatasi missing value, tuliskan dalam Python
#
# 3. ubahlah format yang sesuai dengan tugas forecasting (misalkan nilai harus bernilai integer, dan kalimat harus bernilai string, dll), tuliskan dalam Python
#
# 4. apakah perlu ada normalisasi pada dataset? jika iya, metode normalisasi apa yang anda gunakan? jelaskan pilihan anda, tuliskan dalam Python
#
# 5. pisahkan dataset menjadi data latih dan data uji menggunakan Python sklearn train test split yang sebelumnya perlu dipisahkan terlebih dahulu variable X merupakan independent variable dan variable y merupakan dependent variable, tuliskan dalam Python

# %%
#MASUKAN JAWABAN B1 disini (jika jawaban merupakan isian, gunakan comment Python
# 1. Tujuan forecasting yaitu dengan memprediksi harga di tahun selanjutnya akan naik atau turun
# 2. Dengan menghapus baris atau kolom yang kosong
# 3. Mengubah format variabel mejadi string
bmw["model"] = bmw["model"].astype("string")
bmw["transmission"] = bmw["transmission"].astype("string")
bmw["fuelType"] = bmw["fuelType"].astype("string")
# 4. Tidak perlu normalisasi datashet menurut saya karena
# 5. 
print(bmw.shape)
train=bmw.iloc[:-30]
test=bmw.iloc[-30:]
print(train.shape,test.shape)
# Out:
# (10781, 9)
# (10751, 9) (30, 9)

# %% [markdown]
# # **TOPIK: DATA PREPROCESSING FOR CLUSTERING (B2)**

# %% [markdown]
# 1. Berdasarkan data A2 yang sudah anda baca, jelaskan tujuan dari forecasting apa yang ingin dilakukan?
#
# 2. jelaskan bagaimana cara mengatasi missing value, tuliskan dalam Python
#
# 3. ubahlah format yang sesuai dengan tugas clustering (misalkan nilai harus bernilai integer, dan kalimat harus bernilai string, dll) atau tugas lainnya.. tuliskan dalam Python
#
# 4. apakah perlu ada normalisasi pada dataset? jika iya, metode normalisasi apa yang anda gunakan? jelaskan pilihan anda, tuliskan dalam Python
#
# 5. pisahkan dataset menjadi data latih dan data uji menggunakan Python sklearn train test split yang sebelumnya perlu dipisahkan terlebih dahulu variable X merupakan independent variable dan variable y merupakan dependent variable, tuliskan dalam Python

# %%
# 1. Clustering yang dilakukan adalah mengelompokkan data dalam hal ini pembagian ke dalam kelompok pelanggan terpisah yang memiliki karakteristik serupa
# 2. Pertama cek apakah ada missing value di dalam dataset, di dataset mall tidak ada missing value
# 4. Tidak menggunakan normalisasi data


df_mall = pd.read_csv("/content/drive/My Drive/datasheet/Mall_Customers.csv")
df_mall.isnull().sum()

df_mall.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
# x sebagai variable independent
# y sebagai variable independent
from sklearn.model_selection import train_test_split
X = df_mall.iloc[:, 0:3]
y = df_mall.iloc[:,3:5]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)
X_train
# Out:
#      CustomerID  Gender  Age
# 156         157    Male   37
# 115         116  Female   19
# 155         156  Female   27
# 15           16    Male   22
# 61           62    Male   19
# ..          ...     ...  ...
# 0             1    Male   19
# 184         185  Female   41
# 131         132    Male   39
# 152         153  Female   44
# 106         107  Female   66
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 156                  78                       1
# 115                  65                      50
# 155                  78                      89
# 15                   20                      79
# 61                   46                      55
# ..                  ...                     ...
# 0                    15                      39
# 184                  99                      39
# 131                  71                      75
# 152                  78                      20
# 106                  63                      50
#
# [160 rows x 2 columns]

# %% [markdown]
# # **TOPIK: DATA PREPROCESSING FOR CLASSIFICATION (B3)**

# %% [markdown]
# 1. Berdasarkan data A3 yang sudah anda baca, jelaskan tujuan dari forecasting apa yang ingin dilakukan?
#
# 2. jelaskan bagaimana cara mengatasi missing value, tuliskan dalam Python
#
# 3. ubahlah format yang sesuai dengan tugas classification (misalkan nilai harus bernilai integer, dan kalimat harus bernilai string, dll) atau tugas lainnya.. tuliskan dalam Python
#
# 4. apakah perlu ada normalisasi pada dataset? jika iya, metode normalisasi apa yang anda gunakan? jelaskan pilihan anda, tuliskan dalam Python
#
# 5. pisahkan dataset menjadi data latih dan data uji menggunakan Python sklearn train test split yang sebelumnya perlu dipisahkan terlebih dahulu variable X merupakan independent variable dan variable y merupakan dependent variable, tuliskan dalam Python

# %%
#MASUKAN JAWABAN B3 disini (jika jawaban merupakan isian, gunakan comment Python #

# 1. Mengimpor library, mengimpor datasheet, membagi data ke dalam training dan test set, menerapkan feature scalling
# 2. Dapat dihapus atau diubah menjadi rata rata nilai
# 3. 
voice["skew"] = voice["skew"].astype("int")
voice["kurt"] = voice["kurt"].astype("int")
# 4. Tidak perlu normalisasi pada datasheet
# 5. 
# Mengimpor library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
 
# Mengimpor dataset
X = voice.drop(['label'], axis=1)
y = voice['label']
 
# Membagi data ke dalam training dan test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)
 
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() 
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
voice
# Out:
#       meanfreq        sd    median  ...   dfrange   modindx   label
# 0     0.059781  0.064241  0.032027  ...  0.000000  0.000000    male
# 1     0.066009  0.067310  0.040229  ...  0.046875  0.052632    male
# 2     0.077316  0.083829  0.036718  ...  0.007812  0.046512    male
# 3     0.151228  0.072111  0.158011  ...  0.554688  0.247119    male
# 4     0.135120  0.079146  0.124656  ...  5.476562  0.208274    male
# ...        ...       ...       ...  ...       ...       ...     ...
# 3163  0.131884  0.084734  0.153707  ...  4.203125  0.161929  female
# 3164  0.116221  0.089221  0.076758  ...  3.640625  0.277897  female
# 3165  0.142056  0.095798  0.183731  ...  2.929688  0.194759  female
# 3166  0.143659  0.090628  0.184976  ...  3.585938  0.311002  female
# 3167  0.165509  0.092884  0.183044  ...  0.546875  0.350000  female
#
# [3168 rows x 21 columns]

# %% [markdown]
# # **TOPIK: DATA DEPENDENCY VISUALIZATION (C1)**

# %% [markdown]
# 1. pada dataset A1 dan B1, identifikasi korelasi antara feature (independent variable) dan dependent variable dengan matrix korelasi, tuliskan dalam Python
# 2. pada no.1, bagian mana yang memiiki korelasi yang kuat, jelaskan alasan nya
# 3. gambarkan visualisasi dari feature
# 4. gambarkan visualisasi dari class label
# 5. gambarkan visualisasi dari atribut
# 6. gambarkan visualisasi dari aliran data

# %%
#MASUKAN JAWABAN C1 disini (jika jawaban merupakan isian, gunakan comment Python #
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_bmw = pd.read_csv("/content/drive/My Drive/datasheet/bmw.csv")
plt.figure(figsize=(7,7))
plt.title('Matriks Korelasi Mobil BMW')

sns.heatmap(df_bmw.corr(), annot=True)


# 2. Yang memiliki korelasi kuat adalah Year dan Engine size karena memiliki nilai korelasi bernilai 1

# %% [markdown]
# # **TOPIK: DATA FORECASTING (D1)**

# %% [markdown]
# 1. Berdasarkan data A1, tentukan feature yang akan digunakan
# 2. Buatlah rencana plan forecasting
# 3. Interpretasikan data menuju variable yang dapat digunakan
# 4. apakah dataset ini cocok untuk forecasting?
# 5. analisa atribut yang memiliki korelasi tinggi?
# 6. pilih feature yang digunakan untuk forecasting
# 7. pilih algoritma forecasting yang tepat
# 8. pilih Hyperparameter yang tepat
# 9. analisa dataset secara sederhana
# 10. analisa performa dari forecasting
# 11. analisa akurasi dari forecasting
# 12. analisa f-measure dengan sklearn

# %%
#MASUKAN JAWABAN D1 disini (jika jawaban merupakan isian, gunakan comment Python #
# 1. Feature yang digunakan merupakan salah satu method yang ada di ARIMA itu sendiri.
# 2. Forecast akan menggunakan plan ARIMA
# 3. Data sudah diubah tipe data setiap variabelnya, yang mana variabel pentingnya adalah engineSize
# 4. Cocok, tetapi hasil masih belum sesuai dengan kenyataanya.
# 5. Atribut yang memiliki korelasi tinggi yaitu year dan engineSize
# 6. feature forecasting akan menggunakan methode ARIMA
# 7. Algoritma
# 8. - Membaca Data Anda
# - Plot data Anda
# - Terakhir, Tentukan Model ARIMA Anda
# - Pisahkan Set Data Anda 
# - Sampai ke Juicy Stuff!
# - Periksa Seberapa Bagus Model Anda
# 9. Datasheet tersebut merupakan kumpulan berbagai kumpulan mobil bekas di Inggris Raya yang mana variabel tersebut diantara lain, 
# model,year,price,transmission,mileage,fuelType,tax,mpg,engineSize
# 10. Forecasting menunjukan hasil yang kurang baik dimana harga prediksi tetap dan tidak naik turun
# 11. Akurasi dari forecasting merupakan suatu hal yang kurang beruntung dimana hasil forecasting cukup jauh dari kenyataanya.
# 12. F-Measure menggunakan Sklearn merupakan salah satu perhitungan evalusasi dalam informasi temu kembali yang mengkombinasikan recall dan precission.
bmwnew =bmw.dropna()
print('Shape of data',bmwnew.shape)
from statsmodels.tsa.stattools import adfuller
def ad_test(bmwnew):
     bmwtest = adfuller(bmwnew, autolag = 'AIC')
     print("1. ADF : ",bmwtest[0])
     print("2. P-Value : ", bmwtest[1])
     print("3. Num Of Lags : ", bmwtest[2])
     print("4. Num Of Observations Used For ADF Regression:",      bmwtest[3])
     print("5. Critical Values :")
     for key, val in bmwtest[4].items():
         print("\t",key, ": ", val)
ad_test(bmwnew['price'])
# Out:
# Shape of data (10781, 9)
# 1. ADF :  -6.439592013006368
# 2. P-Value :  1.6205451192757835e-08
# 3. Num Of Lags :  39
# 4. Num Of Observations Used For ADF Regression: 10741
# 5. Critical Values :
# 	 1% :  -3.4309589622460916
# 	 5% :  -2.861809127133186
# 	 10% :  -2.5669132512355715

# %%
bmw
# Out:
#            model  year  price transmission  ...  fuelType  tax   mpg  engineSize
# 0       5 Series  2014  11200    Automatic  ...    Diesel  125  57.6         2.0
# 1       6 Series  2018  27000    Automatic  ...    Petrol  145  42.8         2.0
# 2       5 Series  2016  16000    Automatic  ...    Diesel  160  51.4         3.0
# 3       1 Series  2017  12750    Automatic  ...    Diesel  145  72.4         1.5
# 4       7 Series  2014  14500    Automatic  ...    Diesel  160  50.4         3.0
# ...          ...   ...    ...          ...  ...       ...  ...   ...         ...
# 10776         X3  2016  19000    Automatic  ...    Diesel  150  54.3         2.0
# 10777   5 Series  2016  14600    Automatic  ...    Diesel  125  60.1         2.0
# 10778   3 Series  2017  13100       Manual  ...    Petrol  200  42.8         2.0
# 10779   1 Series  2014   9930    Automatic  ...    Diesel   30  64.2         2.0
# 10780         X1  2017  15981    Automatic  ...    Diesel  125  57.6         2.0
#
# ...

# %%
# !pip install pmdarima
bmw = pd.read_csv("/content/drive/My Drive/datasheet/bmw.csv")
bmw
from pmdarima import auto_arima
stepwise_fit = auto_arima(bmw['price'], trace=True,
suppress_warnings=True)
# Out:
# ...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=229000.382, Time=13.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=234212.572, Time=0.34 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=231705.511, Time=0.75 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=229466.982, Time=1.99 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=234210.572, Time=0.23 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=229010.546, Time=8.49 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=229069.970, Time=5.58 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=229001.109, Time=7.68 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=228982.638, Time=27.83 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=228981.392, Time=14.95 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=229013.197, Time=5.34 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=228970.582, Time=19.82 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=228977.855, Time=8.11 sec
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA
modelbmw=ARIMA(train['price'],order=(0,1,5))
modelbmw=modelbmw.fit()
modelbmw.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...

# %%
start=len(train)
end=len(train)+len(test)+2
pred=modelbmw.predict(start=start,end=end,typ='levels').rename('ARIMA Predictions')
pred.plot(legend=True)
test['price'].plot(legend=True)

# %% [markdown]
# # **TOPIK: DATA CLUSTERING (E1)**

# %% [markdown]
# 1. Berdasarkan data A2, tentukan feature yang akan digunakan
# 2. Buatlah rencana plan clustering
# 3. Interpretasikan data menuju variable yang dapat digunakan
# 4. apakah dataset ini cocok untuk clustering?
# 5. analisa atribut yang memiliki korelasi tinggi?
# 6. pilih feature yang digunakan untuk clustering
# 7. pilih algoritma clustering yang tepat
# 8. pilih Hyperparameter yang tepat
# 9. analisa dataset secara sederhana
# 10. analisa homogenity dari clustering
# 11. analisa heterogenity dari clustering
# 12. analisa kualitas clustering dengan sklearn

# %%
''' 1. Metode yang digunakan Elbow Method
    2. - Menghapus kolom id karena tidak relevan dengan konteksnya
       - Menghitung jumlah kesalahan kuadrat dalam cluster Within Cluster Sum of Squared Errors (WSS) untuk nilai k yang berbeda
       - Memvisualisasikan skor belanja pelanggan dengan pendapatan tahunan  
       - Titik data dipisahkan menjadi 5 kelas yang direpresentasikan dalam warna berbeda

    3. 
    4. Cocok, karena data dapat dikelompokkan terpisah namun memiliki karakteristik serupa(pengelompokkan pelanggan), dan berkemungkinan dapat digunakan 
       untuk kepentingan mall terkait, misalnya menentukan harga produk yang tepat
    5. Atribut yang memiliki korelasi tinggi adalah Customer dan Spending score karena memiliki nilai korelasi 1
    6. Feature yang digunakan adalah Elbow Method
    7. Algoritma yang dipakai adalah KMeans
    8. Hyperparamater berupa df_mall dan wcss
    9. Dataset tersebut merupakan data pembagian pasar ke dalam kelompok pelanggan terpisah yang memiliki karakteristik serupa
    10. Data homogenety dari clustering tersebut adalah Gender
    11. Data heterogenity dari clustering tersebut adalah Spending score
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df_mall = pd.read_csv("/content/drive/My Drive/datasheet/Mall_Customers.csv")
df_mall.drop(["CustomerID"], axis = 1, inplace=True)

from sklearn.cluster import KMeans
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(df_mall.iloc[:,1:])
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("Within Cluster Sum Of Squares (WCSS)")
plt.show()


plt.figure(figsize=(7,7))
plt.title('Matriks Korelasi Customer Mall')

sns.heatmap(df_mall.corr(), annot=True)

# %%
km = KMeans(n_clusters=5)
clusters = km.fit_predict(df_mall.iloc[:,1:])
df_mall["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_mall.Age[df_mall.label == 0], df_mall["Annual Income (k$)"][df_mall.label == 0], df_mall["Spending Score (1-100)"][df_mall.label == 0], c='blue', s=60)
ax.scatter(df_mall.Age[df_mall.label == 1], df_mall["Annual Income (k$)"][df_mall.label == 1], df_mall["Spending Score (1-100)"][df_mall.label == 1], c='red', s=60)
ax.scatter(df_mall.Age[df_mall.label == 2], df_mall["Annual Income (k$)"][df_mall.label == 2], df_mall["Spending Score (1-100)"][df_mall.label == 2], c='green', s=60)
ax.scatter(df_mall.Age[df_mall.label == 3], df_mall["Annual Income (k$)"][df_mall.label == 3], df_mall["Spending Score (1-100)"][df_mall.label == 3], c='orange', s=60)
ax.scatter(df_mall.Age[df_mall.label == 4], df_mall["Annual Income (k$)"][df_mall.label == 4], df_mall["Spending Score (1-100)"][df_mall.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()

# %%
# Mengimpor library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
 
# Mengimpor dataset
X = df_mall.drop(['Gender'], axis=1)
y = df_mall['Gender']
 
# Membagi data ke dalam training dan test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 99)
 
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() 
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)
 
#KNN
from sklearn.neighbors import KNeighborsClassifier
# mengaktikan fungsi klasifikasi untuk knn
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit (X_train,y_train)

y_pred = knn.predict(X_test)
knn.predict_proba(X_test)

from sklearn.metrics import classification_report, confusion_matrix
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n      Female       0.65      0.80      0.71        25\n        Male       0.44      0.27      0.33        15\n\n    accuracy                           0.60        40\n   macro avg       0.54      0.53      0.52        40\nweighted avg       0.57      0.60      0.57        40\n'

# %% [markdown]
# # **TOPIK: DATA CLASSIFICATION (F1)**

# %% [markdown]
# 1. Berdasarkan data A3, tentukan feature yang akan digunakan
# 2. Buatlah rencana plan Classification
# 3. Interpretasikan data menuju variable yang dapat digunakan
# 4. apakah dataset ini cocok untuk Classification?
# 5. analisa atribut yang memiliki korelasi tinggi?
# 6. pilih feature yang digunakan untuk Classification
# 7. pilih algoritma Classification yang tepat
# 8. pilih Hyperparameter yang tepat
# 9. analisa dataset secara sederhana
# 10. analisa performa dari Classification
# 11. analisa akurasi dari Classification
# 12. analisa f-measure dengan sklearn

# %%
''' 1. Feature yang akan digunakan adalah K-Nearest Neighbors
2. classificasion akan menggunakan plan K-Nearest Neighbors yang mana untuk mengklasifikasi objek baru berdasarkan atribut dan training samples.
Dimana hasil dari sampel uji yang baru diklasifikasikan berdasarkan mayoritas dari kategori pada k-NN.
3. Variabel sudah tentu dapat digunakan, semua kolom variabel merupakan independen variabel yang mana variabel tersebut berdiri sendiri, kecuali kolom  variabel label, 
karena hasil dari kolom tersebut bergantung dengan kolom kolom yang lain.
4. Cocok
5. 'meanfreq' dan 'meanfun'
6. KNN (K-Nearest Neighbors)
7. Algoritma yang akan digunakan adalah algoritma yang ada di metode 'K-Nearest Neighbors', karena kita menjalankan metode tersebut.
8. Hyperparameter menunjukan pada variabel maxdom dan meanfreq
9. Analisa datasheet = datasheet tersebut menunjukan data data kumpulan dari suara suara manusia yang digunakan untuk mengenali gendernya.
 Terdiri dari kolom meanfreq, sd, median, Q25, Q75, IQR, skew, kurt, sp.ent, sfm, mode, centroid, meanfun, minfun, maxfun, meandom, mindom, maxdom,
 dfrange, modindx, dan label.
10. Analisa performa classificasion klasifikasi dengan methon KNN merujuk pada beberapa variabel yang mana dapat digunakan untuk mengetahui suara dari gender apa 
tersebut telah dibuktikan sendiri dan memiliki nilai akurasi yang cukuo tinggi.
11. analisa akurasi classificasion = 98%
12. analisa f-measure salah satu perhitungan evalusasi dalam informasi temu kembali yang mengkombinasikan recall dan precission.

# %%
voice.head()
# Out:
#    meanfreq        sd    median       Q25  ...    maxdom   dfrange   modindx  label
# 0  0.059781  0.064241  0.032027  0.015071  ...  0.007812  0.000000  0.000000   male
# 1  0.066009  0.067310  0.040229  0.019414  ...  0.054688  0.046875  0.052632   male
# 2  0.077316  0.083829  0.036718  0.008701  ...  0.015625  0.007812  0.046512   male
# 3  0.151228  0.072111  0.158011  0.096582  ...  0.562500  0.554688  0.247119   male
# 4  0.135120  0.079146  0.124656  0.078720  ...  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
#MASUKAN JAWABAN F1 disini (jika jawaban merupakan isian, gunakan comment Python #
 
#KNN
from sklearn.neighbors import KNeighborsClassifier
# mengaktikan fungsi klasifikasi untuk knn
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit (X_train,y_train)

y_pred = knn.predict(X_test)
knn.predict_proba(X_test)

from sklearn.metrics import classification_report, confusion_matrix
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n      female       0.97      0.98      0.98       301\n        male       0.98      0.97      0.98       333\n\n    accuracy                           0.98       634\n   macro avg       0.98      0.98      0.98       634\nweighted avg       0.98      0.98      0.98       634\n'
